# %% [markdown]
# # Students Performance Dataset: Understanding Dataset & Data Types
#
# The objective is to understand dataset structure, data types, missing values, and ML readiness.

# %% [markdown]
# ## Importing Required Libraries
#
# Pandas is used for data loading and data analysis.

# %%
import pandas as pd

# %% [markdown]
# ## Loading the Students Performance Dataset
#
# The dataset is loaded from the local file `students.csv`.

# %%
students_df = pd.read_csv("students.csv")
students_df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## Viewing First and Last Records
#
# This helps in understanding the structure of rows and columns in the dataset.

# %%
students_df.head()
students_df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %% [markdown]
# ## Dataset Structure and Data Types
#
# `students_df.info()` displays column names, data types, and non-null counts.

# %%
students_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## Statistical Summary of Numerical Features
#
# `students_df.describe()` provides count, mean, standard deviation, minimum, maximum, and quartile values.

# %%
students_df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## Missing Values Analysis
#
# This helps identify data quality issues such as missing values.

# %%
students_df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# ## Unique Values in Each Column
#
# This is used to understand categorical data distribution.

# %%
for col in students_df.columns:
      print("\nColumn:", col)
      print(students_df[col].unique())
# Out:
# Column: gender
# ['female' 'male']
#
# Column: race/ethnicity
# ['group B' 'group C' 'group A' 'group D' 'group E']
#
# Column: parental level of education
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
#
# Column: lunch
# ['standard' 'free/reduced']
#
# Column: test preparation course
# ['none' 'completed']
#
# Column: math score
# [ 72  69  90  47  76  71  88  40  64  38  58  65  78  50  18  46  54  66
#   44  74  73  67  70  62  63  56  97  81  75  57  55  53  59  82  77  33
#   52   0  79  39  45  60  61  41  49  30  80  42  27  43  68  85  98  87
#   51  99  84  91  83  89  22 100  96  94  48  35  34  86  92  37  28  24
#   26  95  36  29  32  93  19  23   8]
#
# Column: reading score
# [ 72  90  95  57  78  83  43  64  60  54  52  81  53  75  89  32  42  58
#   69  73  71  74  70  65  87  56  61  84  55  44  41  85  59  17  39  80
#   37  63  51  49  26  68  45  47  86  34  79  66  67  91 100  76  77  82
# ...

# %% [markdown]
# ## Dataset Size
#
# The shape of the dataset shows the number of rows and columns.

# %%
students_df.shape
# Out:
# (1000, 8)

# %% [markdown]
# ## Feature Classification – Students Performance Dataset
#
# ### Numerical:
# - math score
# - reading score
# - writing score
#
# ### Categorical:
# - gender
# - race/ethnicity
# - parental level of education
# - lunch
# - test preparation course
#
# ### Target Variable:
# - math score (can also be reading or writing score depending on objective)
#
# ### Input Features:
# - All remaining columns

# %% [markdown]
# ## Dataset Suitability for Machine Learning
#
# The dataset has good data quality with minimal missing values and is suitable for machine learning tasks such as regression and classification after proper preprocessing.
